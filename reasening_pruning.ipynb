# %%
# !git clone https://github.com/avrymi-asraf/reasoning-pruning.git

# %%
import sys
sys.path.append('/content/reasoning-pruning/src')
from reasoning_pruning.data_creation import build_pruning_transition_row

# %%
build_pruning_transition_row()
